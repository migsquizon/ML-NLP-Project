# %% [markdown]
# # Part 2 HMM

# %% [markdown]
# ## Loading dataset

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ### Loading sg dataset

# %%
# print(data.head())
numpy_sg = []
lines = np.loadtxt('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/SG/train.txt',delimiter="\n",dtype='str',comments=None)
for line in lines: 
    lst = line.split(' ')
    if len(lst)<2:
        print(lst)
        continue
    numpy_sg.append(np.array(lst))
# numpy_sg = np.array(df)

        
print(numpy_sg[:10])
sg_label_count = dict()
for i in numpy_sg:
#     print(i)
    if len(i) <2:
#         print(i)
        continue
    sg_label_count[i[1]] = sg_label_count.get(i[1], 0) + 1
# print(sglabel_count)


sg_word_count = dict()
for i in numpy_sg:
#     print(i)
    if len(i) <2:
#         print(i)
        continue
    sg_word_count[i[0]] = sg_word_count.get(i[0], 0) + 1
# print(sgword_count)


sg_y_to_x = dict()
for i in numpy_sg:
    if len(i) <2:
#         print(i)
        continue
    sg_y_to_x[i[0]+i[1]] = sg_y_to_x.get(i[0]+i[1], 0) + 1
    
# print(sg_y_to_x)
# Out:
# ['#이_해시는_정국아_생일축하해_를_외치고_싶으나_생일축하_해시를_알지_못하여_외칠_수_없는_이의_한을_담은_해시이며_이_해시를']
# [array(["I'm", 'O'], dtype='<U3'), array(['about', 'O'], dtype='<U5'), array(['to', 'O'], dtype='<U2'), array(['see', 'O'], dtype='<U3'), array(['Adam', 'B-positive'], dtype='<U10'), array(['Levine', 'I-positive'], dtype='<U10'), array(['and', 'O'], dtype='<U3'), array(["I'm", 'O'], dtype='<U3'), array(['probably', 'O'], dtype='<U8'), array(['going', 'O'], dtype='<U5')]

# %% [markdown]
# # Loading EN

# %%
## EN
data_en = pd.read_csv('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/EN/train.txt', sep=" ", header=None)
numpy_en = data_en.to_numpy()
data_en.columns = ["text", "label"]
en_label_count = dict()
for i in data_en["label"]:
    en_label_count[i] = en_label_count.get(i, 0) + 1    
en_word_count = dict()
for i in numpy_en[:,0]:
    en_word_count[i] = en_word_count.get(i, 0) + 1
    

en_y_to_x = dict()
for i in numpy_en[:]:
    en_y_to_x[i[0]+i[1]] = en_y_to_x.get(i[0]+i[1], 0) + 1
    

    

def get_y_to_y(path):   
    try:
        f = open(path,encoding = 'utf-8')
        try_y = f.readlines()
    finally:
        f.close()    
    sentences = []
    sentences.append('START')
    for line in try_y:
        x = line.split(' ')
    #     print(x)
        if len(x) <2:
            # linebreak
            sentences.append('STOP')
            sentences.append('START')
        else:
            sentences.append(x)
    en_states = []
    for term in range(len(sentences)-1):
        if len(sentences[term])==2:
            en_states.append(sentences[term][1])
        else:
            en_states.append(sentences[term])
    for state in range(len(en_states)):
        en_states[state] = en_states[state].rstrip()
    return en_states

en_states = get_y_to_y("/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/EN/train.txt")
# print(en_states)
en_y_to_y = dict()
for i in range(len(en_states)-1):
    en_y_to_y[en_states[i]+ ' ' +en_states[i+1]] = en_y_to_y.get(en_states[i]+ ' '+en_states[i+1], 0) + 1 
    
# print(numpy_en[:30])
# print(en_y_to_y)

en_label_count_with_ss = dict()
for i in en_states:
    en_label_count_with_ss[i] = en_label_count_with_ss.get(i, 0) + 1 

# print(en_y_to_x)
# print(en_word_count)    
# print(en_label_count)
# print(en_label_count_with_ss)
# total = 0
# for val in en_y_to_y.values():
#     total += val
# print(total)
    
# print(label_count.keys())
# print(len(numpy_en))
# Out:
# {'START B-NP': 4966, 'B-NP I-NP': 32390, 'I-NP B-VP': 7365, 'B-VP B-ADVP': 570, 'B-ADVP B-ADJP': 59, 'B-ADJP I-ADJP': 490, 'I-ADJP I-ADJP': 84, 'I-ADJP B-PP': 164, 'B-PP B-NP': 17064, 'I-NP B-PP': 8544, 'I-NP O': 12410, 'O O': 2710, 'O B-ADJP': 209, 'B-NP B-VP': 6164, 'B-VP B-PP': 1803, 'I-NP I-NP': 22201, 'O STOP': 7598, 'STOP START': 7662, 'B-VP B-SBAR': 467, 'B-SBAR B-NP': 1657, 'B-VP B-NP': 6304, 'B-VP O': 1231, 'O B-NP': 8288, 'I-NP B-NP': 2601, 'B-ADVP B-PP': 608, 'B-VP I-VP': 6828, 'I-VP B-NP': 3610, 'O B-VP': 2746, 'I-VP I-VP': 3331, 'B-NP O': 3830, 'B-NP B-PP': 2744, 'I-VP B-PP': 1507, 'B-PP B-PP': 340, 'B-NP B-NP': 1367, 'I-NP B-SBAR': 348, 'B-SBAR B-VP': 73, 'B-NP B-ADVP': 464, 'B-ADVP B-NP': 750, 'B-ADVP I-ADVP': 310, 'I-ADVP B-NP': 68, 'START B-PP': 833, 'I-VP B-SBAR': 134, 'I-VP B-ADVP': 382, 'B-ADVP O': 946, 'I-NP B-ADVP': 837, 'I-ADVP B-ADVP': 11, 'O B-PP': 1197, 'START O': 1087, 'I-VP O': 576, 'B-VP B-PRT': 204, 'B-PRT B-NP': 237, 'B-ADVP B-VP': 770, 'O B-ADVP': 697, 'B-PP B-VP': 489, 'B-NP B-ADJP': 152, 'B-ADJP B-PP': 428, 'I-ADVP O': 119, 'B-VP B-VP': 132, 'O B-SBAR': 385, 'I-ADJP B-NP': 51, 'B-NP B-SBAR': 161, 'B-VP B-ADJP': 716, 'B-ADJP B-VP': 194, 'I-NP B-ADJP': 224, 'B-ADJP O': 450, 'B-ADJP B-NP': 91, 'START B-ADVP': 416, 'B-PP O': 156, 'B-ADVP B-SBAR': 58, 'I-VP B-VP': 84, 'I-ADJP O': 184, 'START B-ADJP': 25, 'B-PP I-PP': 207, 'I-PP B-NP': 175, 'B-ADVP B-ADVP': 58, 'START B-SBAR': 173, 'I-PP B-VP': 7, 'I-ADJP B-SBAR': 35, 'B-ADJP B-ADVP': 28, 'B-PP B-ADJP': 48, 'B-PRT B-PP': 113, 'I-ADVP B-PP': 56, 'I-VP B-ADJP': 295, 'I-ADVP I-ADVP': 53, 'I-VP B-PRT': 237, 'B-ADJP B-SBAR': 66, 'START B-CONJP': 2, 'B-CONJP I-CONJP': 46, 'I-CONJP B-NP': 28, 'START B-VP': 143, 'B-SBAR B-PP': 27, 'B-NP B-PRT': 17, 'I-ADVP B-SBAR': 29, 'B-PRT B-ADVP': 14, 'I-NP STOP': 43, 'B-PRT O': 74, 'O B-INTJ': 14, 'B-INTJ I-INTJ': 5, 'I-INTJ O': 5, 'I-PP B-ADJP': 1, 'B-INTJ O': 16, 'B-SBAR B-SBAR': 16, 'I-PP B-PP': 14, 'I-ADVP B-VP': 21, 'B-PP B-ADVP': 61, 'B-SBAR O': 54, 'B-SBAR B-ADVP': 17, 'B-INTJ B-VP': 2, 'I-PP O': 9, 'I-ADJP B-VP': 40, 'START B-INTJ': 10, 'B-SBAR I-SBAR': 48, 'I-SBAR B-NP': 46, 'B-PP B-SBAR': 18, 'I-NP B-PRT': 7, 'O B-CONJP': 25, 'I-CONJP I-CONJP': 18, 'I-CONJP B-PP': 7, 'I-ADJP B-ADVP': 8, 'B-PRT B-VP': 20, 'B-PRT B-SBAR': 9, 'I-PP I-PP': 16, 'B-VP B-CONJP': 3, 'I-CONJP B-VP': 10, 'B-PP STOP': 4, 'B-SBAR B-ADJP': 6, 'I-SBAR B-PP': 1, 'B-PRT B-ADJP': 1, 'I-ADJP B-ADJP': 7, 'I-NP B-CONJP': 11, 'I-ADVP B-ADJP': 6, 'B-NP STOP': 11, 'B-NP B-UCP': 1, 'B-UCP I-UCP': 1, 'I-UCP I-UCP': 3, 'I-UCP B-NP': 1, 'O B-PRT': 1, 'B-ADJP B-PRT': 1, 'START B-LST': 8, 'B-LST O': 11, 'B-ADJP B-ADJP': 2, 'B-ADVP B-CONJP': 2, 'B-CONJP O': 3, 'B-NP B-CONJP': 4, 'B-ADVP STOP': 3, 'I-SBAR B-VP': 1, 'I-CONJP O': 1, 'I-ADJP STOP': 1, 'I-PP B-ADVP': 1, 'I-VP B-CONJP': 2, 'I-VP STOP': 1, 'I-INTJ I-INTJ': 2, 'B-ADJP STOP': 1, 'B-SBAR B-LST': 1, 'O B-LST': 2, 'B-INTJ B-NP': 1, 'B-VP B-INTJ': 2, 'B-INTJ B-ADVP': 1, 'B-ADVP B-PRT': 1, 'B-VP STOP': 1, 'B-INTJ B-PP': 1}

# %% [markdown]
# # AL

# %%
## AL
data_al = pd.read_csv('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/AL/train.txt', sep=" ", header=None)

data_al.columns = ["text", "label"]
data_al = data_al.replace(np.nan, '', regex=True)
numpy_al = data_al.to_numpy()
al_label_count = dict()
for i in data_al["label"]:
    al_label_count[i] = al_label_count.get(i, 0) + 1   
al_word_count = dict()
for i in numpy_al[:,0]:
    al_word_count[i] = al_word_count.get(i, 0) + 1
    
al_y_to_x = dict()
for i in numpy_al[:]:
#     print(i)
    al_y_to_x[i[0]+i[1]] = al_y_to_x.get(i[0]+i[1], 0) + 1
    
# print(al_y_to_x)
# print(al_label_count)
# print(al_word_count)

# %% [markdown]
# # CN

# %%
## CN
data_cn = pd.read_csv('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/CN/train.txt', sep=" ", header=None)
numpy_cn = data_cn.to_numpy()
data_cn.columns = ["text", "label"]
cn_label_count = dict()
for i in data_cn["label"]:
    cn_label_count[i] = cn_label_count.get(i, 0) + 1
cn_word_count = dict()
for i in numpy_cn[:,0]:
    cn_word_count[i] = cn_word_count.get(i, 0) + 1  
    
cn_y_to_x = dict()
for i in numpy_cn[:]:
#     print(i)
    cn_y_to_x[i[0]+i[1]] = cn_y_to_x.get(i[0]+i[1], 0) + 1
    
# print(cn_y_to_x)
# print(cn_word_count)
# print(cn_label_count)

# %% [markdown]
# ## a
# Write a function that estimates the emission parameters from the training set using MLE (maximum
# likelihood estimation):
# e(x|y) = Count(y → x) / Count(y)

# %%
def smoothing(numpy,word_dict,k=3):
    array = numpy.copy()
    #     print(array[0])
    for tup in array:
#         if tup[0] == '#UNK#':
#             continue
        if word_dict[tup[0]] < k:
            tup[0] = '#UNK#'
    return array

def get_emission_parameter(x,y,array,label_dict):
    count_y_to_x = 0
    for tup in range(len(array)):
        if array[tup][0] == x:
            if array[tup][1] == y:
                count_y_to_x += 1        
    emission = count_y_to_x / label_dict[y]
    return emission



def try_emission(x,y,xy_dict,label_dict):
    if x+y not in xy_dict:
        return 0.0
    count_y_to_x = xy_dict[x+y]
    count_y = label_dict[y]
    return count_y_to_x/count_y
    

    
smoothed_en = smoothing(numpy_en,en_word_count)
smoothed_al = smoothing(numpy_al,al_word_count)
smoothed_cn = smoothing(numpy_cn,cn_word_count)
# smoothed_sg = smoothing(numpy_sg,sg_word_count)

print(try_emission('are','B-VP',en_y_to_x,en_label_count))
print(try_emission('asdasd','B-VP',en_y_to_x,en_label_count))
# print(get_emission_parameter('are','B-VP',smoothed_en,en_label_count))
# Out:
# 0.03707354471277586
# 0.0

# %%
# def smoothing_emission(x,y,numpy,k=3):
#     array = numpy.copy()
# #     print(array[0])
#     for tup in array:
#         if tup[0] == '#UNK#':
#             continue
#         if en_word_count[tup[0]] < k:
#             tup[0] = '#UNK#'        
# #     print(array[0])
#     result = get_emission_parameter(x,y,array)    
#     return result

# for x in smoothed_sg:
#     print(x)
# print(smoothing_emission('municipal','I-NP',numpy_en))

# %%
# writing to python file
# file = open('try.out','w',encoding = 'utf-8')
# file.write("trying out\n")
# file.write('try again\n')
# file.write('1')
# file.close()
# read = open('try.out','r',encoding = 'utf-8')
# read = read.readlines()
# print(read)

# %% [markdown]
# ## Eval Script

# %%
import sys
import re
from copy import copy
from collections import defaultdict
from optparse import OptionParser

# try:
#     f = open("/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/EvalScript/dev.out",encoding = 'utf-8')
#     data = f.readlines()
# finally:
#     f.close()

# print(data)
# print(len(data))
# print(data[:10])

#Read entities from predcition
def get_predicted(predicted, answers=defaultdict(lambda: defaultdict(defaultdict))):

    example = 0
    word_index = 0
    entity = []
    last_ne = "O"
    last_sent = ""
    last_entity = []

    answers[example] = []
    for line in predicted:
        line = line.strip()
#         print(line)
        if line.startswith("##"):
            continue
        elif len(line) == 0:
            if entity:
                answers[example].append(list(entity))
                entity = []

            example += 1
            answers[example] = []
            word_index = 0
            last_ne = "O"
            continue
        else:
            split_line = line.split(separator)
            #word = split_line[0]
            value = split_line[outputColumnIndex]
            ne = value[0]
            sent = value[2:]


            last_entity = []

            #check if it is start of entity
            if ne == 'B' or (ne == 'I' and last_ne == 'O') or (last_ne != 'O' and ne == 'I' and last_sent != sent):
                if entity:
                    last_entity = list(entity)

                entity = [sent]
                    
                entity.append(word_index)

            elif ne == 'I':
                entity.append(word_index)

            elif ne == 'O':
                if last_ne == 'B' or last_ne == 'I':
                    last_entity =list(entity)
                entity = []


            if last_entity:
                answers[example].append(list(last_entity))
                last_entity = []

        last_sent = sent
        last_ne = ne
        word_index += 1

    if entity:
        answers[example].append(list(entity))


    return answers



#Read entities from gold data
def get_observed(observed):


    example = 0
    word_index = 0
    entity = []
    last_ne = "O"
    last_sent = ""
    last_entity = []

    observations=defaultdict(defaultdict)
    observations[example] = []

    for line in observed:
        line = line.strip()
#         print(line)
        if line.startswith("##"):
            continue
        elif len(line) == 0:
            if entity:
                observations[example].append(list(entity))
                entity = []

            example += 1
            observations[example] = []
            word_index = 0
            last_ne = "O"
            continue

        else:
            split_line = line.split(separator)
            word = split_line[0]
            value = split_line[outputColumnIndex]
            ne = value[0]
            sent = value[2:]


            last_entity = []

            #check if it is start of entity, suppose there is no weird case in gold data
            if ne == 'B' or (ne == 'I' and last_ne == 'O') or (last_ne != 'O' and ne == 'I' and last_sent != sent):
                if entity:
                    last_entity = entity

                entity = [sent]
                    
                entity.append(word_index)

            elif ne == 'I':
                entity.append(word_index)

            elif ne == 'O':
                if last_ne == 'B' or last_ne == 'I':
                    last_entity = entity
                entity = []


            if last_entity:
                observations[example].append(list(last_entity))
                last_entity = []


        last_ne = ne
        last_sent = sent
        word_index += 1

    if entity:
        observations[example].append(list(entity))

    return observations

#Print Results and deal with division by 0
def printResult(evalTarget, num_correct, prec, rec):
    if abs(prec + rec ) < 1e-6:
        f = 0
    else:
        f = 2 * prec * rec / (prec + rec)
    print('#Correct', evalTarget, ':', num_correct)
    print(evalTarget, ' precision: %.4f' % (prec))
    print(evalTarget, ' recall: %.4f' %   (rec))
    print(evalTarget, ' F: %.4f' % (f))

#Compare results bewteen gold data and prediction data
def compare_observed_to_predicted(observed, predicted):

    correct_sentiment = 0
    correct_entity = 0

    total_observed = 0.0
    total_predicted = 0.0

    #For each Instance Index example (example = 0,1,2,3.....)
    for example in observed:
        observed_instance = observed[example]
        predicted_instance = predicted[example]

        #Count number of entities in gold data
        total_observed += len(observed_instance)
        #Count number of entities in prediction data
        total_predicted += len(predicted_instance)

        #For each entity in prediction
        for span in predicted_instance:
            span_begin = span[1]
            span_length = len(span) - 1
            span_ne = (span_begin, span_length)
            span_sent = span[0]

            #For each entity in gold data
            for observed_span in observed_instance:
                begin = observed_span[1]
                length = len(observed_span) - 1
                ne = (begin, length)
                sent = observed_span[0]

                #Entity matched
                if span_ne == ne:
                    correct_entity += 1
                    

                    #Entity & Sentiment both are matched
                    if span_sent == sent:
                        correct_sentiment += 1

    print()
    print('#Entity in gold data: %d' % (total_observed))
    print('#Entity in prediction: %d' % (total_predicted))
    print()

    prec = correct_entity/total_predicted
    rec = correct_entity/total_observed
    printResult('Entity', correct_entity, prec, rec)
    print()

    prec = correct_sentiment/total_predicted
    rec = correct_sentiment/total_observed
    printResult('Sentiment',correct_sentiment, prec, rec)

# %% [markdown]
# ## c)

# %%
def decode(inp,word_dict,label_dict,smooth_numpy,filename,xy_dict):
    result = []
    print(len(inp))
    orig_copy = inp.copy()
    file = open(filename,'w',encoding = 'utf-8')
    
    for word in range(len(inp)):
        if inp[word] not in word_dict:
            inp[word] = '#UNK#'

    for word in range(len(inp)):
        templist = []
        retval = []
        retval.append(orig_copy[word])
#         print(orig_copy[word])
        for label in list(label_dict.keys()):
#             print(templist)
            templist.append(try_emission(inp[word],label,xy_dict,label_dict))
#         print(templist)
        index = np.argmax(templist)
        retval.append(list(label_dict.keys())[index])
        result.append(retval) 
        if(orig_copy[word] == '\n' or not orig_copy[word]):
            file.write('\n')
        else:
            file.write(orig_copy[word]+' ' + list(label_dict.keys())[index]+ '\n')
#         print(result)
    file.close()
    return result

# %% [markdown]
# # EN

# %%
try:
    f = open("/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/EN/dev.in",encoding = 'utf-8')
    dev_en = f.readlines()
finally:
    f.close()
    
for string in range(len(dev_en)):
    dev_en[string] = dev_en[string].rstrip()
    
# print(dev_en[:50])  

# print(data)

# for word in range(len(data)):
#     if data[word] not in en_word_count:
#         data[word] = '#UNK#'
       
# print(data[:75])


#EN    
print(decode(dev_en,en_word_count,en_label_count,smoothed_en,'EN/p2.dev.out',en_y_to_x))


#AL
# print(decode(data,al_word_count,al_label_count))
# Out:
# 27225
# [['HBO', 'B-NP'], ['has', 'B-VP'], ['close', 'B-ADJP'], ['to', 'B-PP'], ['24', 'I-NP'], ['million', 'I-NP'], ['subscribers', 'I-NP'], ['to', 'B-PP'], ['its', 'B-NP'], ['HBO', 'B-NP'], ['and', 'I-UCP'], ['Cinemax', 'B-NP'], ['networks', 'I-NP'], [',', 'O'], ['while', 'B-SBAR'], ['Showtime', 'B-NP'], ['and', 'I-UCP'], ['its', 'B-NP'], ['sister', 'I-NP'], ['service', 'I-NP'], [',', 'O'], ['The', 'B-NP'], ['Movie', 'B-NP'], ['Channel', 'I-NP'], [',', 'O'], ['have', 'I-VP'], ['only', 'I-CONJP'], ['about', 'B-PP'], ['10', 'I-ADVP'], ['million', 'I-NP'], [',', 'O'], ['according', 'B-PP'], ['to', 'B-PP'], ['Paul', 'B-NP'], ['Kagan', 'B-NP'], ['Associates', 'I-NP'], [',', 'O'], ['a', 'B-LST'], ['Carmel', 'B-NP'], [',', 'O'], ['Calif.', 'B-NP'], [',', 'O'], ['research', 'I-NP'], ['firm', 'I-NP'], ['.', 'O'], ['', 'B-NP'], ['WASHINGTON', 'B-NP'], ['LIES', 'B-NP'], ['LOW', 'B-NP'], ['after', 'B-SBAR'], ['the', 'B-NP'], ['stock', 'I-NP'], ['market', 'I-NP'], ["'s", 'B-NP'], ['roller-coaster', 'I-NP'], ['ride', 'I-VP'], ['.', 'O'], ['', 'B-NP'], ['This', 'B-NP'], ['may', 'B-VP'], ['seem', 'B-VP'], ['to', 'B-PP'], ['be', 'I-VP'], ['a', 'B-LST'], ['preposterous', 'B-NP'], ['and', 'I-UCP'], ['utterly', 'B-NP'], ['futile', 'I-NP'], ['effort', 'I-NP'], ['in', 'B-PP'], ['Africa', 'I-NP'], ['.', 'O'], ['', 'B-NP'], ['American', 'B-NP'], ['Express', 'I-NP'], ['Bank', 'I-NP'], ['earnings', 'I-NP'], ['fell', 'B-VP'], ['50', 'I-NP'], ['%', 'I-ADJP'], ['to', 'B-PP'], ['$', 'B-NP'], ['21.3', 'I-NP'], ['million', 'I-NP'], ['from', 'B-PP'], ['$', 'B-NP'], ['42.5', 'I-NP'], ['million', 'I-NP'], ['despite', 'B-PP'], ['a', 'B-LST'], ['29', 'I-NP'], ['%', 'I-ADJP'], ['revenue', 'I-NP'], ['gain', 'I-NP'], ['.', 'O'], ['', 'B-NP'], ['Californians', 'B-NP'], [',', 'O'], ['meanwhile', 'B-ADVP'], [',', 'O'], ['tried', 'B-VP'], ['to', 'B-PP'], ['cope', 'I-VP'], ['with', 'B-PP'], ['still-limited', 'B-NP'], ['services', 'I-NP'], [',', 'O'], ['blocked', 'I-VP'], ['roadways', 'I-NP'], ['and', 'I-UCP'], ['water', 'I-NP'], ['shortages', 'I-NP'], ['in', 'B-PP'], ['the', 'B-NP'], ['aftermath', 'I-NP'], ['of', 'I-PP'], ['the', 'B-NP'], ['tremor', 'I-NP'], ['that', 'B-SBAR'], ['left', 'I-VP'], ['scores', 'I-NP'], ['dead', 'B-ADJP'], ['and', 'I-UCP'], ['injured', 'I-VP'], ['.', 'O'], ['', 'B-NP'], ['This', 'B-NP'], ['year', 'I-NP'], [',', 'O'], ['a', 'B-LST'], ['number', 'I-NP'], ['of', 'I-PP'], ['retail', 'B-NP'], ['leveraged', 'I-ADJP'], ['buyouts', 'B-NP'], ['have', 'I-VP'], ['failed', 'B-VP'], [',', 'O'], ['causing', 'I-VP'], ['jitters', 'B-NP'], ['among', 'I-PP'], ['suppliers', 'I-NP'], [',', 'O'], ['and', 'I-UCP'], ['Mr.', 'B-NP'], ['Merksamer', 'I-NP'], ['apparently', 'B-ADVP'], ['wanted', 'B-VP'], ['assurances', 'B-NP'], ['that', 'B-SBAR'], ['he', 'B-NP'], ['wo', 'B-VP'], ["n't", 'I-VP'], ['have', 'I-VP'], ['delivery', 'I-NP'], ['problems', 'I-NP'], ['.', 'O'], ['', 'B-NP'], ['Mr.', 'B-NP'], ['Juliano', 'I-NP'], ['thinks', 'B-VP'], ['so', 'B-ADJP'], ['.', 'O'], ['', 'B-NP'], ['Assistant', 'O'], ['U.S.', 'I-NP'], ['Attorney', 'I-NP'], ['Terry', 'B-NP'], ['Hart', 'I-NP'], ['of', 'I-PP'], ['Dallas', 'B-NP'], ['says', 'B-VP'], ['the', 'B-NP'], ['government', 'I-NP'], ['will', 'B-VP'], ['oppose', 'B-VP'], ['any', 'B-NP'], ['efforts', 'I-NP'], ['to', 'B-PP'], ['bring', 'I-VP'], ['in', 'B-PP'], ['a', 'B-LST'], ['new', 'I-NP'], ['defense', 'I-NP'], ['team', 'I-NP'], ['because', 'B-SBAR'], ['it', 'B-NP'], ['would', 'B-VP'], ['delay', 'I-VP'], ['a', 'B-LST'], ['retrial', 'B-NP'], ['.', 'O'], ['', 'B-NP'], ['Galveston-Houston', 'B-NP'], ['Co.', 'I-NP'], ['said', 'B-VP'], ['it', 'B-NP'], ['will', 'B-VP'], ['redeem', 'B-NP'], ['all', 'I-ADVP'], ['3,950', 'B-NP'], ['shares', 'I-NP'], ['of', 'I-PP'], ['its', 'B-NP'], ['privately', 'B-ADVP'], ['held', 'I-VP'], ['6.5', 'I-NP'], ['%', 'I-ADJP'], ['convertible', 'B-ADJP'], ['Series', 'I-NP'], ['C', 'I-NP'], ['preferred', 'I-NP'], ['stock', 'I-NP'], ['Nov.', 'B-NP'], ['8', 'B-NP'], ['.', 'O'], ['', 'B-NP'], ['On', 'B-PP'], ['a', 'B-LST'] ...

# %%
##############Main Function##################

# if len(sys.argv) < 3:
#     print ('Please make sure you have installed Python 3.4 or above!')
#     print ("Usage on Windows:  python evalResult.py gold predictions")
#     print ("Usage on Linux/Mac:  python3 evalResult.py gold predictions")
#     sys.exit()

gold = open('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/EN/dev.out', "r", encoding='UTF-8')
prediction = open('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/EN/p2.dev.out', "r", encoding='UTF-8')

#column separator
separator = ' '

#the column index for tags
outputColumnIndex = 1
#Read Gold data
observed = get_observed(gold)

#Read Predction data
predicted = get_predicted(prediction)

#Compare
compare_observed_to_predicted(observed, predicted)
# Out:
# #Entity in gold data: 13179
# #Entity in prediction: 18310
#
# #Correct Entity : 9633
# Entity  precision: 0.5261
# Entity  recall: 0.7309
# Entity  F: 0.6118
#
# #Correct Sentiment : 8530
# Sentiment  precision: 0.4659
# Sentiment  recall: 0.6472
# Sentiment  F: 0.5418

# %% [markdown]
# # AL

# %%
try:
    f = open("/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/AL/dev.in",encoding = 'utf-8')
    dev_al = f.readlines()
finally:
    f.close()
    
# print(dev_al)
    
# print(dev_al)
for string in range(len(dev_al)):
    dev_al[string] = dev_al[string].rstrip()


# print(decode(dev_al,al_word_count,al_label_count,smoothed_al,'AL/p2.dev.out',al_y_to_x))
    
# print(dev_al)

# %%
    
gold = open('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/AL/dev.out', "r", encoding='UTF-8')
prediction = open('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/AL/p2.dev.out', "r", encoding='UTF-8')


#column separator
separator = ' '

#the column index for tags
outputColumnIndex = 1
#Read Gold data
observed = get_observed(gold)

#Read Predction data
predicted = get_predicted(prediction)

#Compare
compare_observed_to_predicted(observed, predicted)
# Out:
# #Entity in gold data: 8408
# #Entity in prediction: 19420
#
# #Correct Entity : 2920
# Entity  precision: 0.1504
# Entity  recall: 0.3473
# Entity  F: 0.2099
#
# #Correct Sentiment : 2381
# Sentiment  precision: 0.1226
# Sentiment  recall: 0.2832
# Sentiment  F: 0.1711

# %% [markdown]
# # CN

# %%
try:
    f = open("/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/CN/dev.in",encoding = 'utf-8')
    dev_cn = f.readlines()
finally:
    f.close()
    
for string in range(len(dev_cn)):
    dev_cn[string] = dev_cn[string].rstrip()
    
# print(dev_cn)
    
print(decode(dev_cn,cn_word_count,cn_label_count,smoothed_cn,'CN/p2.dev.out',cn_y_to_x))
# Out:
# 24225
# [['一', 'I-positive'], ['觉醒', 'O'], ['来天', 'O'], ['都', 'O'], ['黑', 'B-neutral'], ['了', 'O'], ['。', 'O'], ['梦到', 'O'], ['了', 'O'], ['继科', 'B-positive'], ['哥哥', 'I-positive'], ['，', 'O'], ['给', 'O'], ['他', 'B-negative'], ['做饭', 'B-neutral'], ['忙', 'O'], ['得', 'I-positive'], ['团团转', 'O'], ['，', 'O'], ['继科', 'B-positive'], ['哥哥', 'I-positive'], ['很乖', 'O'], ['，', 'O'], ['不怎么', 'O'], ['爱', 'B-negative'], ['说话', 'I-neutral'], ['。', 'O'], ['', 'O'], ['#', 'B-positive'], ['向', 'B-neutral'], ['全世界', 'I-neutral'], ['吃货', 'O'], ['安利', 'O'], ['#', 'B-positive'], ['哑', 'O'], ['壬', 'O'], ['迄', 'O'], ['听到', 'O'], ['看', 'O'], ['完', 'I-negative'], ['就', 'I-negative'], ['怀孕', 'I-positive'], ['了', 'O'], ['的', 'O'], ['演唱', 'O'], ['，', 'O'], ['就', 'I-negative'], ['觉得', 'O'], ['心情', 'O'], ['会', 'O'], ['好', 'O'], ['很', 'O'], ['[', 'O'], ['泪', 'O'], [']', 'O'], ['[', 'O'], ['围脖', 'I-neutral'], [']', 'O'], ['[', 'O'], ['手套', 'I-neutral'], [']', 'O'], ['[', 'O'], ['生病', 'O'], [']', 'O'], ['多', 'O'], ['的', 'O'], ['。', 'O'], ['眶', 'O'], ['贷', 'O'], ['', 'O'], ['专访', 'O'], ['小戏', 'O'], ['骨', 'O'], ['《', 'B-positive'], ['放开', 'I-neutral'], ['那', 'O'], ['三国', 'B-positive'], ['》', 'I-positive'], ['导演', 'I-neutral'], ['：', 'O'], ['剧本', 'O'], ['已改', 'O'], ['12', 'I-neutral'], ['版', 'I-neutral'], ['http://t.cn/Rahttzp', 'O'], ['\u200b', 'O'], ['', 'O'], ['#', 'B-positive'], ['阴阳师', 'I-positive'], ['手游', 'I-positive'], ['#', 'B-positive'], ['低调', 'O'], ['晒', 'O'], ['欧气', 'O'], ['！', 'O'], ['讲真', 'O'], ['，', 'O'], ['我', 'B-neutral'], ['人品', 'O'], ['好', 'O'], ['起来', 'O'], ['我', 'B-neutral'], ['自己', 'I-negative'], ['都', 'O'], ['害怕', 'O'], ['！', 'O'], ['http://t.cn/Rcrp17I', 'O'], ['', 'O'], ['我', 'B-neutral'], ['要是', 'O'], ['个', 'O'], ['男', 'I-negative'], ['的', 'O'], ['一定', 'O'], ['爱死', 'O'], ['李小', 'B-positive'], ['男', 'I-negative'], ['了', 'O'], ['[', 'O'], ['泪', 'O'], [']', 'O'], ['[', 'O'], ['泪', 'O'], [']', 'O'], ['[', 'O'], ['泪', 'O'], [']', 'O'], ['', 'O'], ['她', 'O'], ['加', 'O'], ['佳禾', 'O'], ['，', 'O'], ['嗯', 'O'], ['，', 'O'], ['那', 'O'], ['我', 'B-neutral'], ['叫', 'O'], ['橙天', 'O'], ['好', 'O'], ['了', 'O'], ['。', 'O'], ['哈哈哈', 'O'], ['[', 'O'], ['哈哈', 'O'], [']', 'O'], ['', 'O'], ['“', 'O'], ['曾经沧海', 'O'], ['难为', 'O'], ['水', 'I-negative'], ['，', 'O'], ['他', 'B-negative'], ['乡', 'I-positive'], ['咸鸭蛋', 'O'], ['，', 'O'], ['我', 'B-neutral'], ['实在', 'O'], ['瞧', 'O'], ['不', 'O'], ['上', 'O'], ['。', 'O'], ['”', 'I-negative'], ['@', 'B-neutral'], ['掌阅', 'I-neutral'], ['iReader', 'I-neutral'], ['http://t.cn/RVtTCTb', 'O'], ['', 'O'], ['#', 'B-positive'], ['咖啡', 'B-negative'], ['时光', 'B-neutral'], ['#', 'B-positive'], ['【', 'O'], ['小路', 'O'], ['咖啡馆', 'O'], ['[', 'O'], ['心', 'O'], [']', 'O'], ['】', 'O'], ['人均', 'O'], ['：', 'O'], ['42', 'O'], ['元', 'O'], ['|', 'O'], ['小巧', 'O'], ['精致', 'O'], ['的', 'O'], ['一家', 'I-neutral'], ['咖啡馆', 'O'], ['，', 'O'], ['装修', 'O'], ['很', 'O'], ['治愈', 'O'], ['系', 'I-positive'], ['[', 'O'], ['好', 'O'], ['喜欢', 'O'], [']', 'O'], ['环境', 'O'], ['挺舒服', 'O'], ['，', 'O'], ['老板', 'B-negative'], ['服务', 'I-neutral'], ['很', 'O'], ['好', 'O'], ['，', 'O'], ['就', 'I-negative'], ['在', 'O'], ['老舍', 'O'], ['故居', 'O'], ['斜对面', 'O'], ['，', 'O'], ['在', 'O'], ['大学', 'B-negative'], ['路上', 'B-neutral'], ['的', 'O'], ['一条', 'O'], ['小', 'I-negative'], ['路上', 'B-neutral'], ['，', 'O'], ['确实', 'O'], ['符合', 'O'], ['小路', 'O'], ['咖啡', 'B-negative'], ['这个', 'O'], ['名字', 'O'], ['，', 'O'], ['自带', 'O'], ['小院', 'O'], ['[', 'O'], ['好棒', 'O'], [']', 'O'], ['地址', 'O'], ['：', 'O'], ['市南区', 'O'], ['大学', 'B-negative'], ['路', 'B-negative'], ['14', 'O'], ['号', 'I-neutral'], ['8', 'I-positive'], ['号楼', 'O'], ['一层', 'O'], ['(', 'I-neutral'], ['老舍', 'O'], ['故居', 'O'], ['斜对面', 'O'], [')', 'I-neutral'], ['来源', 'O'], ['：', 'O'], ['大众', 'B-neutral'], ['点评', 'O'], ['', 'O'], ['【', 'O'], ['贵州', 'B-neutral'], ['从江', 'I-neutral'], ['】', 'O'], ['知道', 'O'], ['这个', 'O'], ['地方', 'O'], ['的', 'O'], ['人', 'I-negative'], ['或许', 'O'], ['不', 'O'], ['多', 'O'], ['，', 'O'], ['若', 'O'], ['提到', 'O'], ['岜', 'B-neut ...

# %%
gold = open('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/CN/dev.out', "r", encoding='UTF-8')
prediction = open('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/CN/p2.dev.out', "r", encoding='UTF-8')

# print(gold.readlines())

#column separator
separator = ' '

#the column index for tags
outputColumnIndex = 1
#Read Gold data
observed = get_observed(gold)

#Read Predction data
predicted = get_predicted(prediction)

#Compare
compare_observed_to_predicted(observed, predicted)
# Out:
# #Entity in gold data: 1478
# #Entity in prediction: 5861
#
# #Correct Entity : 577
# Entity  precision: 0.0984
# Entity  recall: 0.3904
# Entity  F: 0.1572
#
# #Correct Sentiment : 358
# Sentiment  precision: 0.0611
# Sentiment  recall: 0.2422
# Sentiment  F: 0.0976

# %% [markdown]
# # SG

# %%
try:
    f = open("/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/SG/dev.in",encoding = 'utf-8')
    dev_sg = f.readlines()
finally:
    f.close()
    
for string in range(len(dev_sg)):
    dev_sg[string] = dev_sg[string].rstrip()
    
# print(dev_cn)
    
print(decode(dev_sg,sg_word_count,sg_label_count,smoothed_sg,'SG/p2.dev.out',sg_y_to_x))
# Out:
# 50763
# [['Tour', 'B-positive'], ['Scotland', 'B-neutral'], ['followers', 'O'], ['to', 'O'], ['visit', 'O'], ['@beley_crysta2', 'O'], [',', 'I-neutral'], ['@MyExpatJob', 'O'], [',', 'I-neutral'], [',', 'I-neutral'], ['@paridise15', 'O'], [',', 'I-neutral'], ['@JCBlakeney76', 'O'], [',', 'I-neutral'], ['@UnwearyWorld', 'O'], [',', 'I-neutral'], ['@szilviade', 'O'], [',', 'I-neutral'], ['@garrywatts1231', 'O'], ['', 'O'], ['Overwatch', 'B-positive'], [':', 'O'], ['tip', 'O'], ['!', 'O'], ['Roadhog', 'B-negative'], ['is', 'O'], ['fat', 'B-positive'], ['so', 'O'], ["he's", 'O'], ['easier', 'O'], ['to', 'O'], ['hit', 'O'], ['!', 'O'], ['Me', 'I-positive'], [':', 'O'], ['wtf', 'O'], ['blizzard', 'O'], ['', 'O'], ["I'm", 'O'], ['at', 'O'], ['Club', 'I-neutral'], ['Tryst', 'I-neutral'], ['in', 'O'], ['Singapore', 'B-neutral'], ['https://t.co/imMAYtNBjH', 'O'], ['', 'O'], ['@alexiadavis__', 'O'], ['lol', 'O'], ["don't", 'O'], ['start', 'O'], ['this', 'O'], ['Alexia', 'O'], ['', 'O'], ['Fuck', 'O'], ['A', 'I-positive'], ['Release', 'I-positive'], ['Date', 'O'], ['!', 'O'], ['!', 'O'], ['Pre', 'O'], ['Order', 'I-neutral'], ['"', 'O'], ['Space', 'B-neutral'], ['Jams', 'O'], ['"', 'O'], ['11s', 'O'], ['(', 'I-neutral'], ['2016', 'I-neutral'], [')', 'I-neutral'], ['Right', 'O'], ['Now', 'I-positive'], ['And', 'I-neutral'], ['Get', 'I-positive'], ['Them', 'O'], ['Month', 'O'], ['Early', 'O'], ['!', 'O'], ['!', 'O'], ['#AAMU20', 'O'], ['#OAU20', 'O'], ['…', 'O'], ['https://t.co/vr7fVHrnzP', 'O'], ['', 'O'], ['#APPROUD', 'O'], ['.', 'O'], ['Congrats', 'O'], ['to', 'O'], ['all', 'O'], ['the', 'O'], ['AP', 'B-negative'], ['players', 'B-negative'], ['moving', 'O'], ['into', 'O'], ['round', 'O'], ['2', 'I-negative'], ['.', 'O'], ['Too', 'B-positive'], ['many', 'O'], ['to', 'O'], ['list', 'O'], ['.', 'O'], ['Play', 'B-neutral'], ['Hard', 'I-positive'], ['!', 'O'], ['Play', 'B-neutral'], ['Humble', 'O'], ['!', 'O'], ['', 'O'], ['Putin', 'B-negative'], ['is', 'O'], ['trying', 'O'], ['to', 'O'], ['dictate', 'O'], ['to', 'O'], ['america', 'B-neutral'], [',', 'I-neutral'], ['if', 'O'], ['we', 'O'], ["don't", 'O'], ['pick', 'O'], ['Trump', 'B-negative'], ['there', 'O'], ['will', 'O'], ['be', 'O'], ['a', 'O'], ['nuke', 'O'], ['war.If', 'O'], ['we', 'O'], ['do', 'O'], ['pick', 'O'], ['Trump', 'B-negative'], ['we', 'O'], ['will', 'O'], ['be', 'O'], ['cowards', 'O'], [',', 'I-neutral'], ['Putins', 'B-negative'], ['lackeys', 'O'], ['', 'O'], ['Birmingham', 'B-neutral'], ['City', 'I-neutral'], ['.', 'O'], ['I', 'O'], ["don't", 'O'], ['think', 'O'], ['even', 'O'], ['#SteveBruce', 'B-positive'], ['can', 'O'], ['turn', 'O'], ['around', 'O'], ['the', 'O'], ['state', 'I-negative'], ['of', 'I-positive'], ['#AVFC', 'B-negative'], ['#AstonVilla', 'B-negative'], ['#BirminghamCity', 'B-neutral'], ['…', 'O'], ['https://t.co/OV2lEBvXpo', 'O'], ['', 'O'], ['Hello', 'B-positive'], ['Edinburgh', 'B-positive'], ['...', 'O'], ['#', 'O'], ['https://t.co/DfrDSCoR2P', 'O'], ['', 'O'], ['Here', 'O'], ['for', 'O'], ['the', 'O'], ['#PAMevents', 'O'], ['Social', 'I-neutral'], ['Media', 'I-negative'], ['Survey', 'O'], ['Forum', 'I-neutral'], ['.', 'O'], ['(', 'I-neutral'], ['@', 'O'], ['Coutts', 'O'], ['&', 'I-positive'], ['Co', 'I-neutral'], ['in', 'O'], ['London', 'B-neutral'], [',', 'I-neutral'], ['Greater', 'B-neutral'], ['London', 'B-neutral'], [')', 'I-neutral'], ['https://t.co/2H10p4P9Ej', 'O'], ['', 'O'], ["I'm", 'O'], ['at', 'O'], ['Northpoint', 'B-neutral'], ['Shopping', 'I-neutral'], ['Centre', 'I-neutral'], ['in', 'O'], ['Singapore', 'B-neutral'], ['https://t.co/xVBncn2yWK', 'O'], ['', 'O'], ['@hisfriendmic', 'O'], ['@XXL', 'O'], ['no', 'O'], ['.', 'O'], ['It', 'I-positive'], ['XXL', 'O'], ['and', 'O'], ['other', 'O'], ['forms', 'O'], ['of', 'I-positive'], ['mainstream', 'B-negative'], ['media', 'I-negative'], ['will', 'O'], ['twist', 'O'], ['anything', 'O'], ['anti-trump', 'O'], ['.', 'O'], ["O'Shea", 'I-positive'], ['dosent', 'O'], ['like', 'O'], ['either', 'O'], ['.', 'O'], ['' ...

# %%
gold = open('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/SG/dev.out', "r", encoding='UTF-8')
prediction = open('/Users/anthonymunoz/ISTDTerm6/MachineLearning/ML NLP Project/SG/p2.dev.out', "r", encoding='UTF-8')

# print(gold.readlines())

#column separator
separator = ' '

#the column index for tags
outputColumnIndex = 1
#Read Gold data
observed = get_observed(gold)

#Read Predction data
predicted = get_predicted(prediction)

#Compare
compare_observed_to_predicted(observed, predicted)
# Out:
# #Entity in gold data: 4537
# #Entity in prediction: 10673
#
# #Correct Entity : 2308
# Entity  precision: 0.2162
# Entity  recall: 0.5087
# Entity  F: 0.3035
#
# #Correct Sentiment : 1338
# Sentiment  precision: 0.1254
# Sentiment  recall: 0.2949
# Sentiment  F: 0.1759

# %% [markdown]
# # Part 3

# %%
def transmission(u,v,yy_dict,label_dict):
    # u is i , v is i+1
    if u + ' ' + v not in yy_dict:
        return 0.0
    count_u_to_v = yy_dict[u + ' ' + v]
    count_y = label_dict[u]
    result = count_u_to_v/count_y
    return result

transmission('START', 'B-NP',en_y_to_y,en_label_count_with_ss)
# Out:
# 0.6480490669450607
